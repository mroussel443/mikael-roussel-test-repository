# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import metrics
# %matplotlib inline

# %%
admissions = pd.read_csv('../DAT-NYC-9-27/projects/unit-projects/project-2/assets/admissions.csv')

# %%
admissions.describe()
# Out:
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000         NaN        NaN         NaN
# 50%      0.000000         NaN        NaN         NaN
# 75%      1.000000         NaN        NaN         NaN
# max      1.000000  800.000000    4.00000    4.000000

# %%
admissions.isnull().sum()
# Out:
# admit       0
# gre         2
# gpa         2
# prestige    1
# dtype: int64

# %%
admissions.skew()
# Out:
# admit       0.787051
# gre        -0.150127
# gpa        -0.211765
# prestige    0.093663
# dtype: float64

# %%
admissions.kurt()
# Out:
# admit      -1.387513
# gre        -0.330065
# gpa        -0.574623
# prestige   -0.894759
# dtype: float64

# %%
admissions.corr()
# Out:
#              admit       gre       gpa  prestige
# admit     1.000000  0.182919  0.175952 -0.241355
# gre       0.182919  1.000000  0.382408 -0.124533
# gpa       0.175952  0.382408  1.000000 -0.059031
# prestige -0.241355 -0.124533 -0.059031  1.000000

# %%
admissions['admit'].plot(kind="density",
              figsize=(10,10), ylim=(0,2))

plt.vlines(admissions['admit'].mean(),     
           ymin=0, 
           ymax=2,
           linewidth=5.0)

plt.vlines(admissions['admit'].median(),   
           ymin=0, 
           ymax=2, 
           linewidth=2.0,
           color="red")

# %%
admissions['gre'].plot(kind="density",
              figsize=(10,10), ylim=(0,0.005))

plt.vlines(admissions['gre'].mean(),     
           ymin=0, 
           ymax=0.005,
           linewidth=5.0)

plt.vlines(admissions['gre'].median(),   
           ymin=0, 
           ymax=0.005, 
           linewidth=2.0,
           color="red")

# %%
admissions['gpa'].plot(kind="density",
              figsize=(10,10), ylim=(0,1.0))

plt.vlines(admissions['gpa'].mean(),     
           ymin=0, 
           ymax=1.0,
           linewidth=5.0)

plt.vlines(admissions['gpa'].median(),   
           ymin=0, 
           ymax=1.0, 
           linewidth=2.0,
           color="red")

# %%
admissions['prestige'].plot(kind="density",
              figsize=(10,10), ylim=(0,1.0))

plt.vlines(admissions['prestige'].mean(),     
           ymin=0, 
           ymax=1.0,
           linewidth=5.0)

plt.vlines(admissions['prestige'].median(),   
           ymin=0, 
           ymax=1.0, 
           linewidth=2.0,
           color="red")

# %%
admissions['admit'].plot(kind="box",
              figsize=(10,10), ylim=(0,2))

# %%
admissions['gre'].plot(kind="box",
              figsize=(10,10), ylim=(0,1000))

# %%
admissions['gpa'].plot(kind="box",
              figsize=(10,10), ylim=(0,5))

# %%
admissions['prestige'].plot(kind="box",
              figsize=(10,10), ylim=(0,5))

# %%
admissions['admit'].plot(kind="hist",
              figsize=(10,10), ylim=(0,300))

# %%
admissions['gre'].plot(kind="hist",
              figsize=(10,10), ylim=(0,100))

# %%
admissions['gpa'].plot(kind="hist",
              figsize=(10,10), ylim=(0,100))

# %%
admissions['prestige'].plot(kind="hist",
              figsize=(10,10), ylim=(0,200))

# %%
admissions.cov()
# Out:
#              admit           gre        gpa   prestige
# admit     0.217237      9.871271   0.031191  -0.106189
# gre       9.871271  13369.953040  16.824761 -13.648068
# gpa       0.031191     16.824761   0.144879  -0.021260
# prestige -0.106189    -13.648068  -0.021260   0.893654

# %% [markdown]
# Possible issues with the data:
#
# *There are a couple of null values for the predictor variables. This already prevented us from seeing the quartile numbers for these variables. Since there are very few of them, we could remove the rows that contain them.
#
# *The "gre" and "gpa" variables have some outliers that could affect the association negatively.These outliers might need to be removed depending on the results of the model evaluation.
